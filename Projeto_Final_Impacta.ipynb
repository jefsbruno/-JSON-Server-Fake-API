# %% [markdown]
# <a href="https://colab.research.google.com/github/jefsbruno/-JSON-Server-Fake-API/blob/master/Projeto_Final_Impacta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
url = "https://dadosabertos.camara.leg.br/api/v2/deputados?ordem=ASC&ordenarPor=nome"
resultado = requests.get(url)

# %%
deputados = pd.DataFrame(resultado.json()['dados'])

# %%
gastos = []

for id in deputados.id:
  url_despesa = 'https://dadosabertos.camara.leg.br/api/v2/deputados/'+str(id)+'/despesas?ordem=ASC&ano=2023'
  resposta = requests.get(url_despesa)
  gasto = pd.DataFrame(resposta.json()['dados'])
  gasto['id'] = id
  gastos.append(gasto)

# %%
len(gastos)
# Out:
# 513

# %%
total = pd.concat(gastos)

# %%
total.isnull().sum()
# Out:
# ano                    0
# mes                    0
# tipoDespesa            0
# codDocumento           0
# tipoDocumento          0
# codTipoDocumento       0
# dataDocumento          0
# numDocumento           0
# valorDocumento         0
# urlDocumento         397
# nomeFornecedor         0
# cnpjCpfFornecedor      0
# valorLiquido           0
# valorGlosa             0
# numRessarcimento       0
# codLote                0
# parcela                0
# id                     0
# dtype: int64

# %%
del total['urlDocumento']

# %%
del total['dataDocumento']

# %%
total.head()
# Out:
#       ano   mes                                        tipoDespesa  \
# 0  2023.0   9.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1  2023.0  11.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2  2023.0   5.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 3  2023.0   6.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 4  2023.0   7.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#    codDocumento           tipoDocumento  codTipoDocumento    numDocumento  \
# 0     7610066.0  Nota Fiscal Eletrônica               4.0           35537
# 1     7657491.0             Nota Fiscal               0.0              01
# 2     7552621.0             Nota Fiscal               0.0  11533052023001
# 3     7587236.0          Recibos/Outros               1.0  11533062023001
# 4     7587239.0             Nota Fiscal               0.0  11533072023001
#
#    valorDocumento                                     nomeFornecedor  \
# 0           52.98  3XIS COMERCIO VAREJISTA E ATACADISTA DE PAPELA...
# 1           67.30                                   AGUAS CUIABA S.A
# 2           43.20                                   AGUAS CUIABA S.A
# 3           43.20                                   AGUAS CUIABA S.A
# 4           43.20                                   AGUAS CUIABA S.A
#
#   cnpjCpfFornecedor  valorLiquido  valorGlosa numRessarcimento    codLote  \
# 0    42999796000188         52.98         0.0                   1969221.0
# 1    14995581000153         67.30         0.0                   1996163.0
# 2    14995581000153         43.20         0.0                   1938600.0
# 3    14995581000153         43.20         0.0                   1957493.0
# 4    14995581000153         43.20         0.0                   1957494.0
#
#    parcela      id
# 0      0.0  220593
# 1      0.0  220593
# 2      0.0  220593
# 3      0.0  220593
# 4      0.0  220593

# %%
total.shape
# Out:
# (7597, 16)

# %%
total.numRessarcimento.value_counts()
# Out:
#      7339
# 0     258
# Name: numRessarcimento, dtype: int64

# %%
del total['numRessarcimento']

# %%
print(total.shape)
total.drop_duplicates()
print(total.shape)
# Out:
# (7597, 15)
# (7597, 15)

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7597 entries, 0 to 14
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ano                7597 non-null   float64
#  1   mes                7597 non-null   float64
#  2   tipoDespesa        7597 non-null   object
#  3   codDocumento       7597 non-null   float64
#  4   tipoDocumento      7597 non-null   object
#  5   codTipoDocumento   7597 non-null   float64
#  6   numDocumento       7597 non-null   object
#  7   valorDocumento     7597 non-null   float64
#  8   nomeFornecedor     7597 non-null   object
#  9   cnpjCpfFornecedor  7597 non-null   object
#  10  valorLiquido       7597 non-null   float64
#  11  valorGlosa         7597 non-null   float64
#  12  codLote            7597 non-null   float64
#  13  parcela            7597 non-null   float64
#  14  id                 7597 non-null   int64
# dtypes: float64(9), int64(1), object(5)
# memory usage: 949.6+ KB

# %%
total.describe()
# Out:
#           ano          mes  codDocumento  codTipoDocumento  valorDocumento  \
# count  7597.0  7597.000000  7.597000e+03       7597.000000     7597.000000
# mean   2023.0     6.351323  7.322021e+06          1.167566     2006.272297
# std       0.0     3.440943  1.362931e+06          1.583206     4971.238713
# min    2023.0     1.000000  0.000000e+00          0.000000    -1809.510000
# 25%    2023.0     3.000000  7.524823e+06          0.000000      200.000000
# 50%    2023.0     6.000000  7.571125e+06          0.000000      500.000000
# 75%    2023.0     9.000000  7.621929e+06          1.000000     1848.000000
# max    2023.0    12.000000  7.683139e+06          4.000000   164900.000000
#
#         valorLiquido    valorGlosa       codLote      parcela             id
# count    7597.000000   7597.000000  7.597000e+03  7597.000000    7597.000000
# mean     1989.352348     14.908647  1.885739e+06     0.000790  180466.098855
# std      4952.811794    235.786833  3.547783e+05     0.028094   49923.749657
# min     -1809.510000      0.000000  0.000000e+00     0.000000   62881.000000
# 25%       200.000000      0.000000  1.923397e+06     0.000000  160553.000000
# 50%       495.540000      0.000000  1.948976e+06     0.000000  204453.000000
# 75%      1800.000000      0.000000  1.976222e+06     0.000000  220590.000000
# max    164900.000000  14050.000000  2.010889e+06     1.000000  227433.000000

# %%
total.nomeFornecedor.value_counts()
# Out:
# AMORETTO CAFES EXPRESSO LTDA                                399
# WMS COMERCIO DE ARTIGOS DE PAPELARIA LTDA-ME                240
# CEMIG DISTRIBUIÇÃO S.A.                                     201
# CELULAR FUNCIONAL                                           182
# 031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA    168
#                                                            ...
# GISELLE BRUNOR PACHECO EBRAHIM                                1
# ARNS DE OLIVEIRA & ANDREAZZA ADVOGADOS ASSOCIADOS             1
# COTRANS LOCAÇÃO DE VEICULOS LTDA                              1
# GUIA VEICULOS LTDA                                            1
# ALBERTI COMERCIO DE COMBUSTIVEIS LTDA                         1
# Name: nomeFornecedor, Length: 1295, dtype: int64

# %%
total.nomeFornecedor = [str(fornecedor).upper().replace("S.A.", 'S.A').replace('S/A', 'S.A') for fornecedor in total.nomeFornecedor]

# %%
total.nomeFornecedor.value_counts()
# Out:
# AMORETTO CAFES EXPRESSO LTDA                                399
# WMS COMERCIO DE ARTIGOS DE PAPELARIA LTDA-ME                240
# CEMIG DISTRIBUIÇÃO S.A                                      201
# CELULAR FUNCIONAL                                           182
# 031 - 302 NORTE - CASCOL COMBUSTIVEIS PARA VEICULOS LTDA    168
#                                                            ...
# ALMEIDA MIYASAKI & CIA LTDA                                   1
# D R EVANGELISTA - INFORMATICA - ME                            1
# PROMOÇÕES CONSULTORIA E EDITORA PROCEL                        1
# PAPELARIA E PRESENTES GUARARA EIRELI                          1
# PRIMAVIA RENT A CAR LOCADORA DE VEICULOS LTDA - EPP           1
# Name: nomeFornecedor, Length: 1273, dtype: int64

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///dados.abertos.db')

# %%
deputados.to_sql('deputados', engine)
# Out:
# 513

# %%
total.to_sql('despesas_total', engine)
# Out:
# 7597

# %%
#Análise

# %%
total.head()
# Out:
#       ano   mes                                        tipoDespesa  \
# 0  2023.0   9.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1  2023.0  11.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2  2023.0   5.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 3  2023.0   6.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 4  2023.0   7.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#    codDocumento           tipoDocumento  codTipoDocumento    numDocumento  \
# 0     7610066.0  Nota Fiscal Eletrônica               4.0           35537
# 1     7657491.0             Nota Fiscal               0.0              01
# 2     7552621.0             Nota Fiscal               0.0  11533052023001
# 3     7587236.0          Recibos/Outros               1.0  11533062023001
# 4     7587239.0             Nota Fiscal               0.0  11533072023001
#
#    valorDocumento                                     nomeFornecedor  \
# 0           52.98  3XIS COMERCIO VAREJISTA E ATACADISTA DE PAPELA...
# 1           67.30                                   AGUAS CUIABA S.A
# 2           43.20                                   AGUAS CUIABA S.A
# 3           43.20                                   AGUAS CUIABA S.A
# 4           43.20                                   AGUAS CUIABA S.A
#
#   cnpjCpfFornecedor  valorLiquido  valorGlosa    codLote  parcela      id
# 0    42999796000188         52.98         0.0  1969221.0      0.0  220593
# 1    14995581000153         67.30         0.0  1996163.0      0.0  220593
# 2    14995581000153         43.20         0.0  1938600.0      0.0  220593
# 3    14995581000153         43.20         0.0  1957493.0      0.0  220593
# 4    14995581000153         43.20         0.0  1957494.0      0.0  220593

# %%
deputados = pd.read_sql('select * from deputados;', engine)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-f8fdae99b0b4> in <cell line: 1>()
# ----> 1 deputados = pd.read_sql('select * from deputados;', engine)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     588         )
#     589     else:
# --> 590         return pandas_sql.read_query(
#     591             sql,
#     592             index_col=index_col,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1558         args = _convert_params(sql, params)
#    1559
# -> 1560         result = self.execute(*args)
#    1561         columns = result.keys()
#    1562
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1403     def execute(self, *args, **kwargs):
#    1404         """Simple passthrough to SQLAlchemy connectable"""
# -> 1405         return self.connectable.execution_options().execute(*args, **kwargs)
#    1406
#    1407     def read_table(
#
# AttributeError: 'OptionEngine' object has no attribute 'execute'

# %%
deputados.head()
# Out:
#        id                                                uri             nome  \
# 0  220593  https://dadosabertos.camara.leg.br/api/v2/depu...   Abilio Brunini
# 1  204379  https://dadosabertos.camara.leg.br/api/v2/depu...   Acácio Favacho
# 2  220714  https://dadosabertos.camara.leg.br/api/v2/depu...      Adail Filho
# 3  221328  https://dadosabertos.camara.leg.br/api/v2/depu...  Adilson Barroso
# 4  204560  https://dadosabertos.camara.leg.br/api/v2/depu...     Adolfo Viana
#
#    siglaPartido                                         uriPartido siglaUf  \
# 0            PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 1           MDB  https://dadosabertos.camara.leg.br/api/v2/part...      AP
# 2  REPUBLICANOS  https://dadosabertos.camara.leg.br/api/v2/part...      AM
# 3            PL  https://dadosabertos.camara.leg.br/api/v2/part...      SP
# 4          PSDB  https://dadosabertos.camara.leg.br/api/v2/part...      BA
#
#    idLegislatura                                            urlFoto  \
# 0             57  https://www.camara.leg.br/internet/deputado/ba...
# 1             57  https://www.camara.leg.br/internet/deputado/ba...
# 2             57  https://www.camara.leg.br/internet/deputado/ba...
# 3             57  https://www.camara.leg.br/internet/deputado/ba...
# 4             57  https://www.camara.leg.br/internet/deputado/ba...
#
#                               email
# 0   dep.abiliobrunini@camara.leg.br
# 1   dep.acaciofavacho@camara.leg.br
# 2      dep.adailfilho@camara.leg.br
# 3  dep.adilsonbarroso@camara.leg.br
# 4     dep.adolfoviana@camara.leg.br

# %%
total = total.merge(deputados, on=['id'])

# %%
total.head()
# Out:
#       ano   mes                                        tipoDespesa  \
# 0  2023.0   9.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1  2023.0  11.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2  2023.0   5.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 3  2023.0   6.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 4  2023.0   7.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#    codDocumento           tipoDocumento  codTipoDocumento    numDocumento  \
# 0     7610066.0  Nota Fiscal Eletrônica               4.0           35537
# 1     7657491.0             Nota Fiscal               0.0              01
# 2     7552621.0             Nota Fiscal               0.0  11533052023001
# 3     7587236.0          Recibos/Outros               1.0  11533062023001
# 4     7587239.0             Nota Fiscal               0.0  11533072023001
#
#    valorDocumento                                     nomeFornecedor  \
# 0           52.98  3XIS COMERCIO VAREJISTA E ATACADISTA DE PAPELA...
# 1           67.30                                   AGUAS CUIABA S.A
# 2           43.20                                   AGUAS CUIABA S.A
# 3           43.20                                   AGUAS CUIABA S.A
# 4           43.20                                   AGUAS CUIABA S.A
#
#   cnpjCpfFornecedor  ...  parcela      id  \
# 0    42999796000188  ...      0.0  220593
# 1    14995581000153  ...      0.0  220593
# 2    14995581000153  ...      0.0  220593
# 3    14995581000153  ...      0.0  220593
# 4    14995581000153  ...      0.0  220593
#
#                                                  uri            nome  \
# 0  https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 1  https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 2  https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 3  https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 4  https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
#
#    siglaPartido                                         uriPartido siglaUf  \
# 0            PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 1            PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 2            PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 3            PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 4            PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
#
#   idLegislatura                                            urlFoto  \
# 0            57  https://www.camara.leg.br/internet/deputado/ba...
# 1            57  https://www.camara.leg.br/internet/deputado/ba...
# 2            57  https://www.camara.leg.br/internet/deputado/ba...
# 3            57  https://www.camara.leg.br/internet/deputado/ba...
# 4            57  https://www.camara.leg.br/internet/deputado/ba...
#
#                              email
# 0  dep.abiliobrunini@camara.leg.br
# 1  dep.abiliobrunini@camara.leg.br
# 2  dep.abiliobrunini@camara.leg.br
# 3  dep.abiliobrunini@camara.leg.br
# 4  dep.abiliobrunini@camara.leg.br
#
# [5 rows x 23 columns]

# %%
gastos_deputados = total.groupby(['nome', 'siglaPartido']).sum()[['valorDocumento', 'valorLiquido']]
# Out:
# <ipython-input-39-ce7885256e17>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gastos_deputados = total.groupby(['nome', 'siglaPartido']).sum()[['valorDocumento', 'valorLiquido']]

# %%
gastos_deputados = gastos_deputados.sort_values('valorDocumento', ascending=False)

# %%
gastos_deputados.head(10)
# Out:
#                                     valorDocumento  valorLiquido
# nome                  siglaPartido
# Eunício Oliveira      MDB                426525.79     426525.79
# Giacobo               PL                 399579.50     399579.50
# Glaustin da Fokus     PODE               332829.10     332829.10
# Silas Câmara          REPUBLICANOS       292286.00     292286.00
# Gustinho Ribeiro      REPUBLICANOS       261700.00     261700.00
# Hercílio Coelho Diniz MDB                260814.47     260814.47
# Delegado Éder Mauro   PL                 222426.15     222426.15
# Alberto Mourão        MDB                210835.91     210835.91
# Altineu Côrtes        PL                 192900.00     192900.00
# Renilce Nicodemos     MDB                186563.08     185992.00

# %%
gastos_deputados.tail(10)
# Out:
#                                     valorDocumento  valorLiquido
# nome                  siglaPartido
# Josimar Maranhãozinho PL                    236.66        236.66
# Márcio Honaiser       PDT                   227.09        227.05
# Ana Pimentel          PT                    205.60        205.60
# Gilvan da Federal     PL                    200.00        200.00
# Rosângela Moro        UNIÃO                 164.31        164.31
# Amanda Gentil         PP                    150.00        150.00
# Simone Marquetto      MDB                   106.91        106.91
# Rodrigo Valadares     UNIÃO                 100.00        100.00
# Juliana Cardoso       PT                     19.90         19.90
# Marcio Alvino         PL                      3.86          3.86

# %%
print(total)
# Out:
#          ano   mes                                        tipoDespesa  \
# 0     2023.0   9.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 1     2023.0  11.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 2     2023.0   5.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 3     2023.0   6.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 4     2023.0   7.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# ...      ...   ...                                                ...
# 7592  2023.0  11.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 7593  2023.0  12.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 7594  2023.0   7.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 7595  2023.0   7.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
# 7596  2023.0   4.0  MANUTENÇÃO DE ESCRITÓRIO DE APOIO À ATIVIDADE ...
#
#       codDocumento           tipoDocumento  codTipoDocumento     numDocumento  \
# 0        7610066.0  Nota Fiscal Eletrônica               4.0            35537
# 1        7657491.0             Nota Fiscal               0.0               01
# 2        7552621.0             Nota Fiscal               0.0   11533052023001
# 3        7587236.0          Recibos/Outros               1.0   11533062023001
# 4        7587239.0             Nota Fiscal               0.0   11533072023001
# ...            ...                     ...               ...              ...
# 7592     7653404.0             Nota Fiscal               0.0  202300000000841
# 7593     7669768.0             Nota Fiscal               0.0  202300000000918
# 7594     7576526.0             Nota Fiscal               0.0        000013434
# 7595     7576503.0             Nota Fiscal               0.0  202300000000433
# 7596     7543235.0  Nota Fiscal Eletrônica               4.0            39739
#
#       valorDocumento                                     nomeFornecedor  \
# 0              52.98  3XIS COMERCIO VAREJISTA E ATACADISTA DE PAPELA...
# 1              67.30                                   AGUAS CUIABA S.A
# 2              43.20                                   AGUAS CUIABA S.A
# 3              43.20                                   AGUAS CUIABA S.A
# 4              43.20                                   AGUAS CUIABA S.A
# ...              ...                                                ...
# 7592          701.78                                     A MIL INTERNET
# 7593          701.78                                     A MIL INTERNET
# 7594          322.90                   A MIL INTERNET FIBRA OPTICA LTDA
# 7595           70.00                   A MIL INTERNET FIBRA OPTICA LTDA
# 7596           57.96                     BELLER COMERCIO DE PAPEIS LTDA
#
#      cnpjCpfFornecedor  ...  parcela      id  \
# 0       42999796000188  ...      0.0  220593
# 1       14995581000153  ...      0.0  220593
# 2       14995581000153  ...      0.0  220593
# 3       14995581000153  ...      0.0  220593
# 4       14995581000153  ...      0.0  220593
# ...                ...  ...      ...     ...
# 7592    29300721000107  ...      0.0  220552
# 7593    29300721000107  ...      0.0  220552
# 7594    29300721000107  ...      0.0  220552
# 7595    29300721000107  ...      0.0  220552
# 7596    05563868003058  ...      0.0  220552
#
#                                                     uri            nome  \
# 0     https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 1     https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 2     https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 3     https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# 4     https://dadosabertos.camara.leg.br/api/v2/depu...  Abilio Brunini
# ...                                                 ...             ...
# 7592  https://dadosabertos.camara.leg.br/api/v2/depu...           Zucco
# 7593  https://dadosabertos.camara.leg.br/api/v2/depu...           Zucco
# 7594  https://dadosabertos.camara.leg.br/api/v2/depu...           Zucco
# 7595  https://dadosabertos.camara.leg.br/api/v2/depu...           Zucco
# 7596  https://dadosabertos.camara.leg.br/api/v2/depu...           Zucco
#
#       siglaPartido                                         uriPartido siglaUf  \
# 0               PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 1               PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 2               PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 3               PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# 4               PL  https://dadosabertos.camara.leg.br/api/v2/part...      MT
# ...            ...                                                ...     ...
# 7592            PL  https://dadosabertos.camara.leg.br/api/v2/part...      RS
# 7593            PL  https://dadosabertos.camara.leg.br/api/v2/part...      RS
# 7594            PL  https://dadosabertos.camara.leg.br/api/v2/part...      RS
# 7595            PL  https://dadosabertos.camara.leg.br/api/v2/part...      RS
# 7596            PL  https://dadosabertos.camara.leg.br/api/v2/part...      RS
#
#      idLegislatura                                            urlFoto  \
# 0               57  https://www.camara.leg.br/internet/deputado/ba...
# 1               57  https://www.camara.leg.br/internet/deputado/ba...
# 2               57  https://www.camara.leg.br/internet/deputado/ba...
# 3               57  https://www.camara.leg.br/internet/deputado/ba...
# 4               57  https://www.camara.leg.br/internet/deputado/ba...
# ...            ...                                                ...
# 7592            57  https://www.camara.leg.br/internet/deputado/ba...
# 7593            57  https://www.camara.leg.br/internet/deputado/ba...
# 7594            57  https://www.camara.leg.br/internet/deputado/ba...
# 7595            57  https://www.camara.leg.br/internet/deputado/ba...
# 7596            57  https://www.camara.leg.br/internet/deputado/ba...
#
#                                 email
# 0     dep.abiliobrunini@camara.leg.br
# 1     dep.abiliobrunini@camara.leg.br
# 2     dep.abiliobrunini@camara.leg.br
# 3     dep.abiliobrunini@camara.leg.br
# 4     dep.abiliobrunini@camara.leg.br
# ...                               ...
# 7592          dep.zucco@camara.leg.br
# 7593          dep.zucco@camara.leg.br
# 7594          dep.zucco@camara.leg.br
# 7595          dep.zucco@camara.leg.br
# 7596          dep.zucco@camara.leg.br
#
# [7597 rows x 23 columns]

# %%
finalDF = total.to_excel('finaldata.xlsx')
